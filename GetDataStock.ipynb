# %%
# Install yfinance package.
# !pip install yfinance
 
# Import yfinance
import yfinance as yf  

# Install ploty
# !pip install plotly==4.1.0

import plotly.graph_objects as go
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Requirement already satisfied: yfinance in /home/jsa/.local/lib/python2.7/site-packages (0.1.45)
# Requirement already satisfied: pandas>=0.24 in /home/jsa/.local/lib/python2.7/site-packages (from yfinance) (0.24.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jsa/.local/lib/python2.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /home/jsa/.local/lib/python2.7/site-packages (from yfinance) (1.16.5)
# Requirement already satisfied: requests>=2.20 in /home/jsa/.local/lib/python2.7/site-packages (from yfinance) (2.22.0)
# Requirement already satisfied: pytz>=2011k in /home/jsa/.local/lib/python2.7/site-packages (from pandas>=0.24->yfinance) (2019.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/jsa/.local/lib/python2.7/site-packages (from pandas>=0.24->yfinance) (2.8.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jsa/.local/lib/python2.7/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jsa/.local/lib/python2.7/site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jsa/.local/lib/python2.7/site-packages (from requests>=2.20->yfinance) (1.25.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jsa/.local/lib/python2.7/site-packages (from requests>=2.20->yfinance) (2019.9.11)
# Requirement already satisfied: six>=1.5 in /home/jsa/.local/lib/python2.7/site-packages (from python-dateutil>=2.5.0->pandas>=0.24->yfinance) (1.12.0)
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Requirement already satisfied: plotly==4.1.0 in /home/jsa/anaconda2/lib/python2.7/site-packages (4.1.0)
# Requirement already satisfied: six in /home/jsa/.local/lib/python2.7/site-packages (from plotly==4.1.0) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /home/jsa/anaconda2/lib/python2.7/site-packages (from plotly==4.1.0) (1.3.3)

# %%
# Get the data for the stock Apple by specifying the stock ticker, start date, and end date
df = yf.download('AAPL','2018-01-01','2019-01-01')
 
# Plot the close prices
import matplotlib.pyplot as plt
df.Close.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-649d663da56f> in <module>()
# ----> 1 fig = go.Figure(data=[go.Candlestick(x=df['Date'],
#       2                 open=df['Open'],
#       3                 high=df['High'],
#       4                 low=df['Low'],
#       5                 close=df['Close'])])
#
# /home/jsa/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /home/jsa/.local/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
df.loc['2018-12-01': '2018-12-31',['Open', 'Close']].plot(figsize=(15,5));

# %%
df['Close']
# Out:
# Date
# 2018-01-02    172.26
# 2018-01-03    172.23
# 2018-01-04    173.03
# 2018-01-05    175.00
# 2018-01-08    174.35
# 2018-01-09    174.33
# 2018-01-10    174.29
# 2018-01-11    175.28
# 2018-01-12    177.09
# 2018-01-16    176.19
# 2018-01-17    179.10
# 2018-01-18    179.26
# 2018-01-19    178.46
# 2018-01-22    177.00
# 2018-01-23    177.04
# 2018-01-24    174.22
# 2018-01-25    171.11
# 2018-01-26    171.51
# 2018-01-29    167.96
# 2018-01-30    166.97
# 2018-01-31    167.43
# 2018-02-01    167.78
# 2018-02-02    160.50
# 2018-02-05    156.49
# 2018-02-06    163.03
# 2018-02-07    159.54
# 2018-02-08    155.15
# 2018-02-09    156.41
# 2018-02-12    162.71
# 2018-02-13    164.34
#                ...
# 2018-11-15    191.41
# 2018-11-16    193.53
# 2018-11-19    185.86
# 2018-11-20    176.98
# 2018-11-21    176.78
# 2018-11-23    172.29
# 2018-11-26    174.62
# 2018-11-27    174.24
# 2018-11-28    180.94
# 2018-11-29    179.55
# 2018-11-30    178.58
# 2018-12-03    184.82
# 2018-12-04    176.69
# 2018-12-06    174.72
# 2018-12-07    168.49
# 2018-12-10    169.60
# 2018-12-11    168.63
# 2018-12-12    169.10
# 2018-12-13    170.95
# 2018-12-14    165.48
# 2018-12-17    163.94
# 2018-12-18    166.07
# 2018-12-19    160.89
# 2018-12-20    156.83
# 2018-12-21    150.73
# 2018-12-24    146.83
# 2018-12-26    157.17
# 2018-12-27    156.15
# 2018-12-28    156.23
# 2018-12-31    157.74
# Name: Close, Length: 251, dtype: float64
